# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./output/ruotongg_si618_prj1_output_3.csv",delimiter='\t')
df.head()
# Out:
#    userId  avg_preference  std_preference
# 0   28759        1.176724        1.707831
# 1   29054        1.720682        1.980109
# 2   29228        0.978261        1.679492
# 3   30361        1.219626        1.946426
# 4   30903        2.045455        2.058138

# %%
fig1=sns.displot(x=df.avg_preference, kde=True)

# %%
fig1.savefig('./fig/his1.png')

# %%
fig2=sns.displot(x=df.std_preference, kde=True)

# %%
fig2.savefig('./fig/his2.png')

# %%
df[df["avg_preference"]==0]['std_preference'].describe()
# Out:
# count    546.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: std_preference, dtype: float64

# %%
fig3=sns.jointplot(x='avg_preference',y='std_preference',data=df, kind="hex")

# %%
fig3.savefig('./fig/join1.png')
